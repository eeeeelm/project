# %%
import pandas as pd
import math
import numpy as np

# %%
test = pd.read_pickle('data/000018.XSHE.pkl')
test1 = pd.read_pickle('part_data/000018.XSHE.pkl')

# %%
test
# Out:
#             open  close  low  high  volume  money  factor  high_limit  \
# 2023-11-30   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
# 2023-12-01   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
# 2023-12-04   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
# 2023-12-05   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
# 2023-12-06   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
# ...          ...    ...  ...   ...     ...    ...     ...         ...
# 2024-12-02   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
# 2024-12-03   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
# 2024-12-04   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
# 2024-12-05   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
# 2024-12-06   NaN    NaN  NaN   NaN     NaN    NaN     NaN         NaN
#
#             low_limit  avg  pre_close  paused
# 2023-11-30        NaN  NaN        NaN     NaN
# ...

# %%
test1
# Out:
# Empty DataFrame
# Columns: [open_rate, close_rate, low_rate, factor, high_rate, avg, close]
# Index: []

# %%
test = pd.read_pickle('result/origin.pkl')
test1 = pd.read_pickle('result/pred.pkl')

# %%
test
# Out:
# tensor([[[ 8.1800],
#          [ 8.1500],
#          [ 8.1900],
#          ...,
#          [ 8.6500],
#          [ 8.4600],
#          [ 8.8200]],
#
#         [[10.1400],
#          [10.2400],
#          [ 9.8400],
#          ...,
#          [ 6.8500],
#          [ 6.7400],
#          [ 6.8800]],
#
#         [[17.2800],
#          [17.6700],
#          [17.2700],
#          ...,
#          [13.2600],
#          [13.6200],
#          [13.6500]],
#
#         ...,
#
#         [[ 7.1200],
#          [ 7.1400],
#          [ 7.0600],
#          ...,
#          [ 9.2000],
#          [10.0000],
#          [ 9.2100]],
#
#         [[ 3.8300],
#          [ 3.9400],
#          [ 3.8600],
#          ...,
#          [ 3.7600],
#          [ 3.8200],
#          [ 3.8500]],
#
#         [[10.4100],
#          [10.5400],
#          [10.7300],
#          ...,
#          [11.5900],
#          [12.0200],
#          [12.2900]]], device='cuda:0')

# %%
test1
# Out:
# tensor([[[6.1935],
#          [5.8771],
#          [5.6639],
#          ...,
#          [5.6639],
#          [5.6639],
#          [5.6639]],
#
#         [[6.1935],
#          [5.8771],
#          [5.6639],
#          ...,
#          [5.6639],
#          [5.6639],
#          [5.6639]],
#
#         [[6.1935],
#          [5.8771],
#          [5.6639],
#          ...,
#          [5.6639],
#          [5.6639],
#          [5.6639]],
#
#         ...,
#
#         [[6.1935],
#          [5.8771],
#          [5.6639],
#          ...,
#          [5.6639],
#          [5.6639],
#          [5.6639]],
#
#         [[6.1935],
#          [5.8771],
#          [5.6639],
#          ...,
#          [5.6639],
#          [5.6639],
#          [5.6639]],
#
#         [[6.1935],
#          [5.8771],
#          [5.6639],
#          ...,
#          [5.6639],
#          [5.6639],
#          [5.6639]]], device='cuda:0', requires_grad=True)

# %%
(test1[10]-test1[2]).sum()
# Out:
# tensor(0., device='cuda:0', grad_fn=<SumBackward0>)
